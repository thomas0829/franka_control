# %%
import os
import glob
import numpy as np
from tqdm import tqdm

# modify data
dataset = "green_block_corner2"

for split in ["train", "eval"]:
    dataset_path = f"data/{dataset}/" + split
    save_path = f"data/{dataset}_blocking/" + split
    key = "front_rgb"

    file_names = glob.glob(f"{dataset_path}/episode_*.npy")
    assert len(file_names) > 0, f"WARNING: no data in {dataset_path}!"
    
    os.makedirs(save_path, exist_ok=True)

    for file in tqdm(file_names):
        data = np.load(file, allow_pickle=True)
        for i in range(len(data)-1):
            data[i]["action"][...,:6] = data[i+1]["lowdim_ee"][...,:6] - data[i]["lowdim_ee"][...,:6]
        # for i in range(len(data)):
        #     data[i][key] = data[i][key].transpose(1,2,0)
        file = os.path.join(save_path, file.split("/")[-1])
        np.save(file, data)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# 100%|██████████| 10/10 [00:00<00:00, 38.51it/s]
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[1], line 15
#      12 key = "front_rgb"
#      14 file_names = glob.glob(f"{dataset_path}/episode_*.npy")
# ---> 15 assert len(file_names) > 0, f"WARNING: no data in {dataset_path}!"
#      17 os.makedirs(save_path, exist_ok=True)
#      19 for file in tqdm(file_names):
#
# AssertionError: WARNING: no data in data/green_block_corner2/eval!
