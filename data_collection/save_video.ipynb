# %%
# Out:
# found 57 demos
#   2%|▏         | 1/57 [00:00<00:12,  4.48it/s]
# save /home/robots/yuquand/data/date_512/video/bedroom_scene_0/episode_0.mp4
#   4%|▎         | 2/57 [00:00<00:21,  2.55it/s]
# save /home/robots/yuquand/data/date_512/video/bedroom_scene_0/episode_1.mp4
#   5%|▌         | 3/57 [00:01<00:33,  1.63it/s]
# save /home/robots/yuquand/data/date_512/video/kitchen_scene_2/episode_17.mp4
#   7%|▋         | 4/57 [00:02<00:29,  1.80it/s]
# save /home/robots/yuquand/data/date_512/video/kitchen_scene_2/episode_12.mp4
#   9%|▉         | 5/57 [00:02<00:25,  2.05it/s]
# save /home/robots/yuquand/data/date_512/video/kitchen_scene_2/episode_11.mp4
#  11%|█         | 6/57 [00:02<00:24,  2.06it/s]
# save /home/robots/yuquand/data/date_512/video/kitchen_scene_2/episode_15.mp4
#  12%|█▏        | 7/57 [00:03<00:27,  1.79it/s]
# save /home/robots/yuquand/data/date_512/video/kitchen_scene_2/episode_21.mp4
#  14%|█▍        | 8/57 [00:04<00:26,  1.85it/s]
# ...
