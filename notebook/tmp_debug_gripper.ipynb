# %%
from robot.real.server_interface import ServerInterface


ip_address = "192.168.1.6"
robot = ServerInterface(ip_address=ip_address)
# Out:
# ---------------------------------------------------------------------------
# LostRemote                                Traceback (most recent call last)
# Cell In[14], line 5
#       1 from robot.real.server_interface import ServerInterface
#       4 ip_address = "192.168.1.6"
# ----> 5 robot = ServerInterface(ip_address=ip_address)
#
# File ~/polymetis_franka/robot/real/server_interface.py:30, in ServerInterface.__init__(self, ip_address, launch)
#      28 if launch:
#      29     func_list = [self.launch_controller, self.launch_robot]
# ---> 30     attempt_n_times(func_list, max_attempts=2)
#
# File ~/polymetis_franka/robot/real/server_interface.py:13, in attempt_n_times(function_list, max_attempts, sleep_time)
#      11 for i in range(max_attempts):
#      12     try:
# ---> 13         [f() for f in function_list]
#      14         return
#      15     except zerorpc.exceptions.RemoteError as err:
#
# File ~/polymetis_franka/robot/real/server_interface.py:13, in <listcomp>(.0)
# ...

# %%
command = 1.0 # grasp
robot.update_gripper(command=command, velocity=False)

# %%
command = 0.0 # release
robot.update_gripper(command=command, velocity=False)

# %%
robot.server._grasping
