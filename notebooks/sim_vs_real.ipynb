# %%
import joblib
import numpy as np
import matplotlib.pyplot as plt

# %%
filename = "sim_vs_real_24_02_19_11_08_38"
logdir = f"/home/marius/Projects/polymetis_franka/logdir/vs/0/{filename}"
data_dict = joblib.load(logdir)

# %%
obs_real, obs_sim = data_dict["real"], data_dict["sim"]
obs_real.keys(), obs_sim.keys()
# Out:
# (dict_keys(['lowdim_qpos', 'lowdim_ee', '28834630_rgb', '28834630_depth']),
#  dict_keys(['lowdim_qpos', 'lowdim_ee', 'front_rgb', 'front_depth', 'left_rgb', 'left_depth']))

# %%
colors = ['red', 'green', 'blue']
labels = ['x', 'y', 'z']

plt.close()
for i, (c, l) in enumerate(zip(colors, labels)):
    plt.plot(obs_real["lowdim_ee"][:,i], label='real '+l, color=c)
    plt.plot(obs_sim["lowdim_ee"][:,i], label='sim '+l, color=c, linestyle='dashed')

plt.legend()

# %%
plt.imshow(obs_real["28834630_rgb"][0])

# %%
plt.imshow(obs_sim["front_rgb"][0])
