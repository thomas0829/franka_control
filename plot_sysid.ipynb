# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
real = np.load("real.npy")
sim = np.load("sim_weight.npy")

# %%
real.shape, sim.shape
# Out:
# ((20, 6), (50, 2, 3))

# %%
# kd_pos=self.gain_scale * torch.nn.Parameter(torch.tensor(self.metadata["default_Kqd"], dtype=torch.float32)) * 5

plt.close()
for i, (c, d) in enumerate(zip(['x', 'y', 'z'], ['red', 'green', 'blue'])):
    plt.plot(real[:20,i], label='real '+c, color=d)
    plt.plot(sim[:20,0,i], label='sim '+c, color=d, linestyle='dashed')

plt.legend()

# %%
plt.close()
for i, (c, d) in enumerate(zip(['x', 'y', 'z'], ['red', 'green', 'blue'])):
    plt.plot(real[:20,i], label='real '+c, color=d)
    plt.plot(sim[:20,0,i], label='sim '+c, color=d, linestyle='dashed')

plt.legend()
